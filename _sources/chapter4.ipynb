# %% [markdown]
# # 4. 🗃️ Advanced file management
#
# ```{seealso}
# - [Older](./chapter4-old.ipynb) Version
# - [Alternative](./chapter4-alt.ipynb) Version
# ```
#
# Not convered as day 4 coincided with Juneteenth. But [here](https://claude.ai/public/artifacts/20a877ff-9def-4e8c-aaab-7ba239a87b86) are some notes to help get you up to speed
#
# And please review last years lab [here](./lab4_answerkey.md)
