# %% [markdown]
# # 📌 Quick References
#
# ## 🏛️ Room
#
# * **Wolfe W3031**, East Baltimore Campus
# * **All are welcome** to join the in-person vibe – come for the content, stay for the camaraderie
#
# ---
#
# ## 🔗 [Zoom](https://us06web.zoom.us/j/86492592698)
#
# * Every session and lab is **recorded**
# * Videos stay up for **120 days**
# * **Share your screen** freely during lab – that’s where the magic happens
#
# ---
#
# ## 🎥 Recordings
#
# | Day    | Link                                                                                                                                                 |
# | ------ | ---------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **M**  | [Watch](https://us06web.zoom.us/rec/share/k2Ipe53_HMtoF0xMuSDTID_u1vO0bTp0IfIqJ2cCbm1o9JRkB_4IYNlVDEXKsmxt.xKkmdYLm7ZuMudgI?startTime=1750076800000) |
# | **T**  | [Watch](https://us06web.zoom.us/rec/share/LTA7ymPB7IrWcu5g-HXYdFv9KxV_6sFGfHc2bjfiAmd86c8mqW3fmf02mSfaY4e-.Gizs3-8uBT591b-_?startTime=1750162447000) |
# | **W**  | [Watch](https://us06web.zoom.us/rec/share/ely6NylbDX0vaft82kp3oQTL_XQMVpnrHt7E9wzk220OIcub1sTKM_m0teJc36I.BOdcu2LGiwLE5hy5?startTime=1750249747000)  |
# | **Th** | *(TBA)*                                                                                                                                              |
# | **F**  | [Watch](https://us06web.zoom.us/rec/share/1kg23aExzh-vnRJMvb4PAtmGabTSZl2tG-Ocy2eHMaZraGv6XPbdA9Usk8IBcwKN.Uxv66TB6Ggxb25ir?startTime=1750422562000) |
#
# ---
#
# ## 📝 [Syllabus](https://publichealth.jhu.edu/course/41687)
#
# ## 📚 [CoursePlus](https://courseplus.jhu.edu/core/index.cfm/go/home/)
#
# * Video passcodes
# * Discussion forum
# * Lab Dropbox
#
# ---
#
# ## 👨🏽‍🏫 Your Instructor
#
# **Abimereki Muzaale**
# 📧 [muzaale@jhmi.edu](mailto:muzaale@jhmi.edu)
#
# ## 👨🏻‍💻 Co-Instructor
#
# **Vincent Jin**
# 📧 [zjin26@alumni.jh.edu](mailto:zjin26@alumni.jh.edu)
#
# ---
#
# ## 🧪 Labs
#
# Labs due at **11:59 PM** in Dropbox
#
# | Lab          | Link                                         |
# | ------------ | -------------------------------------------- |
# | **M**        | [Lab 1](./lab1_answerkey.md)                 |
# | **T**        | [Lab 2](./lab2_answerkey.md)                 |
# | **W**        | [Lab 3](./lab3_answerkey.md)                 |
# | **Th**       | [Lab 4](./lab4.md) *(practice at your pace)* |
# | **F**        | [Lab 5](./lab5.md)                           |
#
# ---
#
# ## 📦 Datasets
#
# | File               | Formats                                                                                                                 |
# | ------------------ | ----------------------------------------------------------------------------------------------------------------------- |
# | transplants        | [`.dta`](transplants.dta) / [`.txt`](https://raw.githubusercontent.com/jhustata/livre/main/transplants.txt)             |
# | donors             | [`.dta`](donors.dta) / [`.txt`](https://raw.githubusercontent.com/jhustata/livre/main/donors.txt)                       |
# | donors\_recipients | [`.dta`](donors_recipients.dta) / [`.txt`](https://raw.githubusercontent.com/jhustata/livre/main/donors_recipients.txt) |
# | tx\_yr             | [`.dta`](tx_yr.dta) / [`.txt`](https://raw.githubusercontent.com/jhustata/livre/main/tx_yr.txt)                         |
#
# ---
#
# ## 📂 Supplemental Materials
#
# * [lecture1.do](lecture1do.md)
# * [lecture2.do](./lecture2do.md)
# * [lecture3.do](./lecture3do.md)
# * [lecture4.do](./lecture4do.ipynb)
# * [lecture5.do](./lecture5do.md)
# * 📌 A [note](pvalue.ipynb) on **Stata 13**
#
# ---
#
# ## 📖 Catalog
#
# Want a boost? Check the Stata [code catalog](./catalog.md) – not exhaustive, but **damn useful**.
#
# ## 🧠 In-a-Nutshell
#
# See what we [cover](./coda.md) in this whirlwind course.
#
# ## 🤖 Prompt-Based Programming
#
# * A [concrete example](./capture.md) of **prompt-meets-code**.
#
# ---
#
# ## 🧾 [Course Evaluation](https://courseevaluations.jhsph.edu/)
#
# Yes, we read them. Yes, they shape the course.
#
# ---
#
# ## 📣 Announcements
#
# ```{seealso}
# Last updated: 11:15 PM
#
# + Friday video available
# + Please study supplemental `.do` files above
#    + especially study [lecture4.do](./lecture4do.ipynb)
#    + helps with practice in matters of `bys`, `egen`, etc
# + New code drop under [day 5](https://jhustata.github.io/summer/chapter5.html) – we'll break it down together
# + Cross-platform (OS-agnostic) scripting strategies up next!
# ```
#
# ---
#
# ## 🖥️ OS-Agnostic Code Snippet
#
# Write once. Run anywhere.
#
# ```stata
# if "`c(os)'" == "Windows" {
#     local downloads `"c:\Users\`c(username)'\Downloads"'
# }
# else {
#     local downloads "~/Downloads"
# }
# ```
