# %% [markdown]
# # 📌 Quick References
#
# ## Room
#    + Wolfe **W3031**
#    + East Baltimore Campus
#    + You're all welcome to join the in-person experience
#
# ## [Zoom](https://us06web.zoom.us/j/86492592698)
#    + Sessions & labs will be recorded
#    + Videos will remain in the cloud for 120 days
#    + Helpful to share your screen when troubleshooting during lab
#
# ## Recordings
#    + [M](https://us06web.zoom.us/rec/share/k2Ipe53_HMtoF0xMuSDTID_u1vO0bTp0IfIqJ2cCbm1o9JRkB_4IYNlVDEXKsmxt.xKkmdYLm7ZuMudgI?startTime=1750076800000)
#    + [T](https://us06web.zoom.us/rec/share/LTA7ymPB7IrWcu5g-HXYdFv9KxV_6sFGfHc2bjfiAmd86c8mqW3fmf02mSfaY4e-.Gizs3-8uBT591b-_?startTime=1750162447000)
#    + [W](https://us06web.zoom.us/rec/share/ely6NylbDX0vaft82kp3oQTL_XQMVpnrHt7E9wzk220OIcub1sTKM_m0teJc36I.BOdcu2LGiwLE5hy5?startTime=1750249747000)
#    + Th
#    + F
#
# ## [Syllabus](https://publichealth.jhu.edu/course/41687)
#
# ## [CoursePlus](https://courseplus.jhu.edu/core/index.cfm/go/home/)
#    + Content
#       + Video passcodes
#    + Discussion Forum
#    + Lab Dropbox
#
# ## Your Instructor
#    + Abimereki Muzaale muzaale@jhmi.edu
#
# ## Co-Instructor
#    + Vincent Jin zjin26@alumni.jh.edu
#
# ## Labs
#
# Due in DropBox at 11:59 PM
#    + [Lab 1](./lab1_answerkey.md) M
#    + [Lab 2](./lab2_answerkey.md) T
#    + [Lab 3](./lab3_answerkey.md) W
#    + <strike>Lab 4 Th</strike>
#    + Lab 5 F
#    + Optional M (06/23/2025)
#
# ## Datasets
#    + [transplants.dta](transplants.dta)
#    + [transplants.txt](https://raw.githubusercontent.com/jhustata/livre/main/transplants.txt)
#    + [donors.dta](donors.dta)
#    + [donors.txt](https://raw.githubusercontent.com/jhustata/livre/main/donors.txt)
#    + [donors_recipients.dta](donors_recipients.dta)
#    + [donors_recipients.txt](https://raw.githubusercontent.com/jhustata/livre/main/donors_recipients.txt)
#    + [tx_yr.dta](tx_yr.dta)
#    + [tx_yr.txt](https://raw.githubusercontent.com/jhustata/livre/main/tx_yr.txt)
#
# ## Supplemental
#    + [lecture1.do](lecture1do.md)
#    + [lecture2.do](./lecture2do.md)
#    + [lecture3.do](./lecture3do.md)
#    + [lecture4.do](./lecture4do.ipynb)
#    + lecture5.do
#
# A [note](pvalue.ipynb) on Stata 13
#
# ## Catalog
#
# We have a Stata code [catalog](./catalog.md). It's not intended to be comprehensive, but it can prove to be quite convenient as you develop your Stata vocabulary.
#
# ## In-a-Nutshell
#    + Topics [covered](./coda.md) in this course
#
# ## Evaluation
#
# Course [evaluation](https://courseevaluations.jhsph.edu/)
#
# ## Announcements
#
# ```{seealso}
# Last updated: 6:30 PM 06/19/2025
#
# M T W Lab solutions available
# ```
